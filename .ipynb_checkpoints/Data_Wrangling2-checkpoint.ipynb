# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("StudentsPerformanceTest1.csv")

# %%
df
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0  female         72            72           74.0             78.0
# 1  female         69            90           88.0              NaN
# 2  female         90            95           93.0             74.0
# 3    male         47            57            NaN             78.0
# 4    male         na            78           75.0             81.0
# 5  female         71            Na           78.0             70.0
# 6    male         12            44           52.0             12.0
# 7    male        NaN            65           67.0             49.0
# 8    male          5            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
df.isnull()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0   False       False          False          False            False
# 1   False       False          False          False             True
# 2   False       False          False          False            False
# 3   False       False          False           True            False
# 4   False       False          False          False            False
# 5   False       False          False          False            False
# 6   False       False          False          False            False
# 7   False        True          False          False            False
# 8   False       False          False          False            False
#
#    placement offer count  Region
# 0                  False   False
# 1                  False   False
# 2                  False   False
# 3                  False   False
# 4                  False   False
# 5                  False   False
# 6                  False   False
# 7                  False   False
# 8                  False    True

# %%
df.isnull().sum()
# Out:
# gender                   0
# math score               1
# reading score            0
# writing score            1
# Placement Score          1
# placement offer count    0
# Region                   1
# dtype: int64

# %%
series=pd.isnull(df['math score'])

# %%
df[series]
# Out:
#   gender math score reading score  writing score  Placement Score  \
# 7   male        NaN            65           67.0             49.0
#
#    placement offer count Region
# 7                      1   Pune

# %%
df.notnull()
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0    True        True           True           True             True
# 1    True        True           True           True            False
# 2    True        True           True           True             True
# 3    True        True           True          False             True
# 4    True        True           True           True             True
# 5    True        True           True           True             True
# 6    True        True           True           True             True
# 7    True       False           True           True             True
# 8    True        True           True           True             True
#
#    placement offer count  Region
# 0                   True    True
# 1                   True    True
# 2                   True    True
# 3                   True    True
# 4                   True    True
# 5                   True    True
# 6                   True    True
# 7                   True    True
# 8                   True   False

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()

# %%
df['gender']=le.fit_transform(df['gender'])

# %%
df
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0       0         72            72           74.0             78.0
# 1       0         69            90           88.0              NaN
# 2       0         90            95           93.0             74.0
# 3       1         47            57            NaN             78.0
# 4       1         na            78           75.0             81.0
# 5       0         71            Na           78.0             70.0
# 6       1         12            44           52.0             12.0
# 7       1        NaN            65           67.0             49.0
# 8       1          5            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
df.isnull().sum()
# Out:
# gender                   0
# math score               1
# reading score            0
# writing score            1
# Placement Score          1
# placement offer count    0
# Region                   1
# dtype: int64

# %%
df.isna().sum()
# Out:
# gender                   0
# math score               1
# reading score            0
# writing score            1
# Placement Score          1
# placement offer count    0
# Region                   1
# dtype: int64

# %%
df.mean()
# Out:
# C:\Users\Jyotiraditya Biswas\AppData\Local\Temp\ipykernel_15532\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# gender                    0.555556
# writing score            77.000000
# Placement Score          62.125000
# placement offer count     1.777778
# dtype: float64

# %%
df['math score'].fillna(52.285714,axis=0,inplace=True)

# %%
df['reading score'].fillna(72.25,axis=0,inplace=True)

# %%
df['writing score'].fillna(77.0,axis=0,inplace=True)

# %%
df['Placement Score'].fillna(62.125,axis=0,inplace=True)

# %%
df
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0       0         72            72           74.0           78.000
# 1       0         69            90           88.0           62.125
# 2       0         90            95           93.0           74.000
# 3       1         47            57           77.0           78.000
# 4       1         na            78           75.0           81.000
# 5       0         71            Na           78.0           70.000
# 6       1         12            44           52.0           12.000
# 7       1  52.285714            65           67.0           49.000
# 8       1          5            77           89.0           55.000
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
df.drop('Region',axis=1)
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0       0         72            72           74.0           78.000
# 1       0         69            90           88.0           62.125
# 2       0         90            95           93.0           74.000
# 3       1         47            57           77.0           78.000
# 4       1         na            78           75.0           81.000
# 5       0         71            Na           78.0           70.000
# 6       1         12            44           52.0           12.000
# 7       1  52.285714            65           67.0           49.000
# 8       1          5            77           89.0           55.000
#
#    placement offer count
# 0                      1
# 1                      2
# 2                      2
# 3                      1
# 4                      3
# 5                      4
# 6                      2
# 7                      1
# 8                      0

# %%
df2=df.drop('gender',axis=1)

# %%
df2
# Out:
#   math score reading score  writing score  Placement Score  \
# 0         72            72           74.0           78.000
# 1         69            90           88.0           62.125
# 2         90            95           93.0           74.000
# 3         47            57           77.0           78.000
# 4         na            78           75.0           81.000
# 5         71            Na           78.0           70.000
# 6         12            44           52.0           12.000
# 7  52.285714            65           67.0           49.000
# 8          5            77           89.0           55.000
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# 7                      1    Pune
# 8                      0     NaN

# %%
df2.to_csv("raw_data.csv",index=False)

# %%
import seaborn as sns

# %%
sns.boxplot(data=df,x='Placement Score')
# Out:
# <Axes: xlabel='Placement Score'>

# %%
sns.boxplot(data=df,x='writing score')
# Out:
# <Axes: xlabel='writing score'>
